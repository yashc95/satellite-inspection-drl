# %%
"""
Implementation of DDPG - Deep Deterministic Policy Gradient
Algorithm and hyperparameter details can be found here:
    http://arxiv.org/pdf/1509.02971v2.pdf
The algorithm is tested on the Pendulum-v0 OpenAI gym task
and developed with tflearn + Tensorflow
Author: Patrick Emami
"""
import tensorflow as tf
import numpy as np
import gym
from gym import wrappers
import gym_sat_inspection
import tflearn
import argparse
import pprint as pp
import util
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import math
from replay_buffer import ReplayBuffer
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0815 10:49:06.178832 139730476185344 deprecation_wrapper.py:119] From /home/ubuntu/anaconda3/lib/python3.6/site-packages/tflearn/helpers/summarizer.py:9: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# W0815 10:49:06.179996 139730476185344 deprecation_wrapper.py:119] From /home/ubuntu/anaconda3/lib/python3.6/site-packages/tflearn/helpers/trainer.py:25: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# W0815 10:49:06.185330 139730476185344 deprecation_wrapper.py:119] From /home/ubuntu/anaconda3/lib/python3.6/site-packages/tflearn/collections.py:13: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# W0815 10:49:06.188620 139730476185344 deprecation_wrapper.py:119] From /home/ubuntu/anaconda3/lib/python3.6/site-packages/tflearn/config.py:123: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# W0815 10:49:06.194086 139730476185344 deprecation_wrapper.py:119] From /home/ubuntu/anaconda3/lib/python3.6/site-packages/tflearn/config.py:129: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# W0815 10:49:06.194748 139730476185344 deprecation_wrapper.py:119] From /home/ubuntu/anaconda3/lib/python3.6/site-packages/tflearn/config.py:131: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.

# %%
class ActorNetwork(object):
    """
    Input to the network is the state, output is the action
    under a deterministic policy.
    The output layer activation is a tanh to keep the action
    between -action_bound and action_bound
    """

    def __init__(self, sess, state_dim, action_dim, action_bound, learning_rate, tau, batch_size):
        self.sess = sess
        self.s_dim = state_dim
        self.a_dim = action_dim
        self.learning_rate = learning_rate
        self.tau = tau
        self.batch_size = batch_size
        self.action_bound = action_bound
        # Actor Network
        self.inputs, self.out, self.scaled_out = self.create_actor_network()

        self.network_params = tf.trainable_variables()

        # Target Network
        self.target_inputs, self.target_out, self.target_scaled_out= self.create_actor_network()

        self.target_network_params = tf.trainable_variables()[
                                     len(self.network_params):]
        self.saver = tf.train.Saver()

        # Op for periodically updating target network with online network
        # weights
        self.update_target_network_params = \
            [self.target_network_params[i].assign(tf.multiply(self.network_params[i], self.tau) +
                                                  tf.multiply(self.target_network_params[i], 1. - self.tau))
             for i in range(len(self.target_network_params))]
        
        # This gradient will be provided by the critic network
        self.action_gradient = tf.placeholder(tf.float32, [None, self.a_dim])

        # Combine the gradients here
        self.unnormalized_actor_gradients = tf.gradients(
            self.scaled_out, self.network_params, -self.action_gradient)
        self.actor_gradients = list(map(lambda x: tf.div(x, self.batch_size), self.unnormalized_actor_gradients))

        # Optimization Op
        self.optimize = tf.train.AdamOptimizer(self.learning_rate). \
            apply_gradients(zip(self.actor_gradients, self.network_params))

        self.num_trainable_vars = len(
            self.network_params) + len(self.target_network_params)

    def create_actor_network(self):
        inputs = tflearn.input_data(shape=[None, self.s_dim])
        net = tflearn.fully_connected(inputs, 400)
        net = tflearn.layers.normalization.batch_normalization(net)
        net = tflearn.activations.relu(net)
        net = tflearn.fully_connected(net, 300)
        net = tflearn.layers.normalization.batch_normalization(net)
        net = tflearn.activations.relu(net)
        # Final layer weights are init to Uniform[-3e-3, 3e-3]
        w_init = tflearn.initializations.uniform(minval=-0.003, maxval=0.003)
        out = tflearn.fully_connected(
            net, self.a_dim, activation='tanh', weights_init=w_init)
        scaled_out = tf.multiply(out,self.action_bound)
        return inputs, out, scaled_out

    def train(self, inputs, a_gradient):
        self.sess.run(self.optimize, feed_dict={
            self.inputs: inputs,
            self.action_gradient: a_gradient
        })

    def predict(self, inputs):
        return self.sess.run(self.scaled_out, feed_dict={
            self.inputs: inputs
        })

    def predict_target(self, inputs):
        return self.sess.run(self.target_scaled_out, feed_dict={
            self.target_inputs: inputs
        })

    def update_target_network(self):
        self.sess.run(self.update_target_network_params)

    def get_num_trainable_vars(self):
        return self.num_trainable_vars

# %%
class CriticNetwork(object):
    """
    Input to the network is the state and action, output is Q(s,a).
    The action must be obtained from the output of the Actor network.
    """

    def __init__(self, sess, state_dim, action_dim, learning_rate, tau, gamma, num_actor_vars):
        self.sess = sess
        self.s_dim = state_dim
        self.a_dim = action_dim
        self.learning_rate = learning_rate
        self.tau = tau
        self.gamma = gamma

        # Create the critic network
        self.inputs, self.action, self.out = self.create_critic_network()

        self.network_params = tf.trainable_variables()[num_actor_vars:]

        # Target Network
        self.target_inputs, self.target_action, self.target_out = self.create_critic_network()

        self.target_network_params = tf.trainable_variables()[(len(self.network_params) + num_actor_vars):]

        # Op for periodically updating target network with online network
        # weights with regularization
        self.update_target_network_params = \
            [self.target_network_params[i].assign(tf.multiply(self.network_params[i], self.tau) \
                                                  + tf.multiply(self.target_network_params[i], 1. - self.tau))
             for i in range(len(self.target_network_params))]

        # Network target (y_i)
        self.predicted_q_value = tf.placeholder(tf.float32, [None, 1])

        # Define loss and optimization Op
        self.loss = tflearn.mean_square(self.predicted_q_value, self.out)
        self.optimize = tf.train.AdamOptimizer(
            self.learning_rate).minimize(self.loss)

        # Get the gradient of the net w.r.t. the action.
        # For each action in the minibatch (i.e., for each x in xs),
        # this will sum up the gradients of each critic output in the minibatch
        # w.r.t. that action. Each output is independent of all
        # actions except for one.
        self.action_grads = tf.gradients(self.out, self.action)

    def create_critic_network(self):
        inputs = tflearn.input_data(shape=[None, self.s_dim])
        action = tflearn.input_data(shape=[None, self.a_dim])
        net = tflearn.fully_connected(inputs, 400)
        net = tflearn.layers.normalization.batch_normalization(net)
        net = tflearn.activations.relu(net)

        # Add the action tensor in the 2nd hidden layer
        # Use two temp layers to get the corresponding weights and biases
        t1 = tflearn.fully_connected(net, 300)
        t2 = tflearn.fully_connected(action, 300)

        net = tflearn.activation(
            tf.matmul(net, t1.W) + tf.matmul(action, t2.W) + t2.b, activation='relu')

        # linear layer connected to 1 output representing Q(s,a)
        # Weights are init to Uniform[-3e-3, 3e-3]
        w_init = tflearn.initializations.uniform(minval=-0.003, maxval=0.003)
        out = tflearn.fully_connected(net, 1, weights_init=w_init)
        return inputs, action, out

    def train(self, inputs, action, predicted_q_value):
        return self.sess.run([self.out, self.optimize], feed_dict={
            self.inputs: inputs,
            self.action: action,
            self.predicted_q_value: predicted_q_value
        })

    def predict(self, inputs, action):
        return self.sess.run(self.out, feed_dict={
            self.inputs: inputs,
            self.action: action
        })

    def predict_target(self, inputs, action):
        return self.sess.run(self.target_out, feed_dict={
            self.target_inputs: inputs,
            self.target_action: action
        })

    def action_gradients(self, inputs, actions):
        return self.sess.run(self.action_grads, feed_dict={
            self.inputs: inputs,
            self.action: actions
        })

    def update_target_network(self):
        self.sess.run(self.update_target_network_params)

# %%
# Taken from https://github.com/openai/baselines/blob/master/baselines/ddpg/noise.py, which is
# based on http://math.stackexchange.com/questions/1287634/implementing-ornstein-uhlenbeck-in-matlab
class OrnsteinUhlenbeckActionNoise:
    def __init__(self, mu, sigma=0.5, theta=.15, dt=1, x0=None):
        self.theta = theta
        self.mu = mu
        self.sigma = sigma
        self.dt = dt
        self.x0 = x0
        self.reset()

    def __call__(self):
        x = self.x_prev + self.theta * (self.mu - self.x_prev) * self.dt + \
            self.sigma * np.sqrt(self.dt) * np.random.normal(size=self.mu.shape)
        self.x_prev = x
        return x

    def reset(self):
        self.x_prev = self.x0 if self.x0 is not None else np.zeros_like(self.mu)

    def __repr__(self):
        return 'OrnsteinUhlenbeckActionNoise(mu={}, sigma={})'.format(self.mu, self.sigma)

# %%
# ===========================
#   Tensorflow Summary Ops
# ===========================

def build_summaries():
    episode_reward = tf.Variable(0.)
    tf.summary.scalar("Reward", episode_reward)
    episode_ave_max_q = tf.Variable(0.)
    tf.summary.scalar("Qmax Value", episode_ave_max_q)

    summary_vars = [episode_reward, episode_ave_max_q]
    summary_ops = tf.summary.merge_all()

    return summary_ops, summary_vars

# %%
# ===========================
#   Agent Training
# ===========================

def train(sess, env, args, actor, critic, actor_noise):
    # Set up summary Ops
    summary_ops, summary_vars = build_summaries()
    start_steps = int(float(args['max_episodes'])/5)
    zero_steps = 0
    sess.run(tf.global_variables_initializer())
    writer = tf.summary.FileWriter(args['summary_dir'], sess.graph)

    # Initialize target network weights
    actor.update_target_network()
    critic.update_target_network()

    # Initialize replay memory
    replay_buffer = ReplayBuffer(int(args['buffer_size']), int(args['random_seed']))

    # Needed to enable BatchNorm.
    # This hurts the performance on Pendulum but could be useful
    # in other environments.
    # tflearn.is_training(True)

    for i in range(int(args['max_episodes'])):

        s = env.reset()

        ep_reward = 0
        ep_ave_max_q = 0

        for j in range(int(args['max_episode_len'])):

            if args['render_env']:
                env.render()

            # Added exploration noise
            # a = actor.predict(np.reshape(s, (1, 3))) + (1. / (1. + i))
            if i > start_steps:
                a = actor.predict(np.reshape(s, (1, actor.s_dim))) + actor_noise()
                s2, r, terminal, info = env.step(a[0])
            elif i >zero_steps:
                mean = np.array([0,0,0,0])
                cov = np.array([[0.25, 0,0,0], [0, 0.25,0,0],[0,0,0.25,0],[0, 0, 0, 0.25]])
                a = np.random.multivariate_normal(mean, cov, 1)
                a = a[0]
                for k in range(len(a)):
                    val = a[k]
                    if val >=0.5:
                        a[k] = 0.5
                    elif val <=-0.5:
                        a[k] = -0.5
                s2, r, terminal, info = env.step(a)
            else:
                a = np.array([0,0,0,0])
                s2, r, terminal, info = env.step(a)

            replay_buffer.add(np.reshape(s, (actor.s_dim,)), np.reshape(a, (actor.a_dim,)), r,
                              terminal, np.reshape(s2, (actor.s_dim,)))

            # Keep adding experience to the memory until
            # there are at least minibatch size samples
            if replay_buffer.size() > int(args['minibatch_size']):
                s_batch, a_batch, r_batch, t_batch, s2_batch = \
                    replay_buffer.sample_batch(int(args['minibatch_size']))

                # Calculate targets
                target_q = critic.predict_target(
                    s2_batch, actor.predict_target(s2_batch))

                y_i = []
                for k in range(int(args['minibatch_size'])):
                    if t_batch[k]:
                        y_i.append(r_batch[k])
                    else:
                        y_i.append(r_batch[k] + critic.gamma * target_q[k])

                # Update the critic given the targets
                predicted_q_value, _ = critic.train(
                    s_batch, a_batch, np.reshape(y_i, (int(args['minibatch_size']), 1)))

                ep_ave_max_q += np.amax(predicted_q_value)

                # Update the actor policy using the sampled gradient
                a_outs = actor.predict(s_batch)
                grads = critic.action_gradients(s_batch, a_outs)
                actor.train(s_batch, grads[0])

                # Update target networks
                actor.update_target_network()
                critic.update_target_network()

            s = s2
            ep_reward += r

            if terminal:
                summary_str = sess.run(summary_ops, feed_dict={
                    summary_vars[0]: ep_reward,
                    summary_vars[1]: ep_ave_max_q / float(j+1)
                })

                writer.add_summary(summary_str, i)
                writer.flush()
                break
        print('| Reward: {:d} | Episode: {:d} | Qmax: {:.4f}'.format(int(ep_reward), i, (ep_ave_max_q / float(j+1))))
        
    best_RTN,best_reward = env.getBestRun()
    R = [RTN[0] for RTN in best_RTN]
    T = [RTN[1] for RTN in best_RTN]
    N = [RTN[2] for RTN in best_RTN]
    fig = plt.figure(1)
    ax = fig.gca(projection='3d')
    ax.plot(R,T,N,label='RTN for Best Run, Reward ={}'.format(best_reward))

# %%
def test(sess, env, args, actor):
    # Set up summary Ops
    reward_list = []
    action_list = []
    pct_list = []
    for i in range(int(args['test_episodes'])):

        s = env.reset()
        ep_reward = 0

        for j in range(int(args['max_episode_len'])):
            # a = actor.predict(np.reshape(s, (1, 3))) + (1. / (1. + i))
            a = actor.predict(np.reshape(s, (1, actor.s_dim)))
            s2, r, terminal, info = env.step(a[0])
            s = s2
            ep_reward += r
            action_list.append(a)
            if terminal:
                print('| Reward: {:d} | Episode: {:d}'.format(int(ep_reward),                                                                              i))
                reward_list.append(int(ep_reward))
                pct_list.append(env.percent_coverage)
                break
    best_RTN,best_reward = env.getBestRun()
    R = [RTN[0] for RTN in best_RTN]
    T = [RTN[1] for RTN in best_RTN]
    N = [RTN[2] for RTN in best_RTN]
    fig = plt.figure(2)
    ax = fig.gca(projection='3d')
    ax.plot(R,T,N,label='RTN for Best Test Run, Reward ={}'.format(best_reward))
    return reward_list,action_list,pct_list

# %%
def test_rand_policy(env, args):
    # Set up summary Ops
    reward_list = []
    action_list = []
    pct_list = []
    for i in range(int(args['test_episodes'])):

        s = env.reset()
        ep_reward = 0

        for j in range(int(args['max_episode_len'])):
            # a = actor.predict(np.reshape(s, (1, 3))) + (1. / (1. + i))
            mean = np.array([0,0,0,0])
            cov = np.array([[0.25, 0,0,0], [0, 0.25,0,0],[0,0,0.25,0],[0, 0, 0, 0.25]])
            a = np.random.multivariate_normal(mean, cov, 1)
            a = a[0]
            for k in range(len(a)):
                val = a[k]
                if val >=0.5:
                    a[k] = 0.5
                elif val <=-0.5:
                    a[k] = -0.5
            s2, r, terminal, info = env.step(a)
            s = s2
            ep_reward += r
            action_list.append(a)
            if terminal:
                print('| Reward: {:d} | Episode: {:d}'.format(int(ep_reward),                                                                              i))
                reward_list.append(int(ep_reward))
                pct_list.append(env.percent_coverage)
                break
    best_RTN,best_reward = env.getBestRun()
    R = [RTN[0] for RTN in best_RTN]
    T = [RTN[1] for RTN in best_RTN]
    N = [RTN[2] for RTN in best_RTN]
    fig = plt.figure(3)
    ax = fig.gca(projection='3d')
    ax.plot(R,T,N,label='RTN for Best Random Policy Run, Reward ={}'.format(best_reward))
    return reward_list,action_list,pct_list

# %%
def test_zero_policy(env, args):
    # Set up summary Ops
    reward_list = []
    action_list = []
    pct_list = []
    for i in range(int(args['test_episodes'])):

        s = env.reset()
        ep_reward = 0

        for j in range(int(args['max_episode_len'])):
            # a = actor.predict(np.reshape(s, (1, 3))) + (1. / (1. + i))
            a = np.array([0,0,0,0])
            s2, r, terminal, info = env.step(a)
            s = s2
            ep_reward += r
            action_list.append(a)
            if terminal:
                print('| Reward: {:d} | Episode: {:d}'.format(int(ep_reward),                                                                              i))
                reward_list.append(int(ep_reward))
                pct_list.append(env.percent_coverage)
                break
    best_RTN,best_reward = env.getBestRun()
    R = [RTN[0] for RTN in best_RTN]
    T = [RTN[1] for RTN in best_RTN]
    N = [RTN[2] for RTN in best_RTN]
    fig = plt.figure(4)
    ax = fig.gca(projection='3d')
    ax.plot(R,T,N,label='RTN for Best Zero Policy Run, Reward ={}'.format(best_reward))
    return reward_list,action_list,pct_list

# %%
def main(args):
    oe_insp_0 = np.array([6771., 0.0, 0.0, 0.000001, math.radians(5.0), 0.0])
    oe_targ_0 = np.array([6771., 0.0, 0.0, 0.0, math.radians(5.0), 0.0])
    roe_0 = util.ROEfromOEs(oe_insp_0, oe_targ_0)
    dt = 500
    RTN_0 = util.ROE2HILL(roe_0, oe_targ_0[0], oe_targ_0[1])
    w= math.sqrt(398600/math.pow(oe_targ_0[0],3))
    print("W = ",w)
    w_0 = np.array([0, 0, -w])
    Pg_0 = np.array([np.linalg.norm(RTN_0), 0, 0])
    # Array to store "feature points" by theta, phi pair in Geometric frame.
    map_0 = np.zeros((360, 360))
    num_photos = args['max_episode_len']
    tau = 50
    fuel_0 = np.array((0.1,))
    state_0 = np.concatenate((roe_0, Pg_0, w_0, fuel_0),axis = 0)
    kwargs = {'init_state':state_0, 'map': map_0, 'inspOE_0':oe_insp_0, 'targOE_0': oe_targ_0, 'RTN_0': RTN_0, 'dt':dt,'num_photos':num_photos, 'tau': tau}
    with tf.Session() as sess:

            env = gym.make(args['env'],**kwargs)
            np.random.seed(int(args['random_seed']))
            tf.set_random_seed(int(args['random_seed']))
            env.seed(int(args['random_seed']))

            state_dim = len(state_0)
            action_dim = env.action_space.shape[0]
            action_bound = env.action_space.high[0]
            assert(env.action_space.high[0] == -env.action_space.low[0])
            actor = ActorNetwork(sess, state_dim, action_dim, action_bound,
                                 float(args['actor_lr']), float(args['tau']),
                                 int(args['minibatch_size']))

            critic = CriticNetwork(sess, state_dim, action_dim,
                                   float(args['critic_lr']), float(args['tau']),
                                   float(args['gamma']),
                                   actor.get_num_trainable_vars())

            actor_noise = OrnsteinUhlenbeckActionNoise(mu=np.zeros(action_dim))

            if args['use_gym_monitor']:
                if not args['render_env']:
                    env = wrappers.Monitor(
                        env, args['monitor_dir'], video_callable=False, force=True)
                else:
                    env = wrappers.Monitor(env, args['monitor_dir'], force=True)
            print('Beginning Training')
            train(sess, env, args, actor, critic, actor_noise)
            save_path = actor.saver.save(sess, "./results/model.ckpt")
            if args['use_gym_monitor']:
                env.monitor.close()
            print('Beginning Testing')
            """
                new_saver = tf.train.import_meta_graph('./results/model.ckpt.meta')
                new_saver.restore(sess, tf.train.latest_checkpoint('./results/'))
            """
            reward_list,action_list,pct_list = test(sess, env, args, actor)
            print('Reward List',reward_list)
            print('Actions List', action_list)
            print('Average Reward',np.average(reward_list))
            print('Average Pct Coverage',np.average(pct_list))
            
            print('Testing a Random Policy')
            rand_list, rand_actions,pct_list_rand = test_rand_policy(env, args)
            print('Reward List for Random Policy',rand_list)
            print('Actions List for Random Policy ',rand_actions)
            print('Average Reward for Random Policy ',np.average(rand_list))
            print('Average Pct Coverage for Random Policy ',np.average(pct_list_rand))
            
            print('Testing a Zero Policy')
            zero_list, zero_actions,pct_list_zero = test_zero_policy(env, args)
            print('Reward List for Zero Policy',zero_list)
            print('Actions List for Zero Policy ',zero_actions)
            print('Average Reward for Zero Policy ',np.average(zero_list))
            print('Average Pct Coverage for Zero Policy ',np.average(pct_list_zero))
            
            plt.figure(5)
            plt.plot(reward_list, color = "blue")
            plt.plot(rand_list, color = "red")
            plt.plot(zero_list,color = "green")
            plt.legend()
            plt.title('Reward Comparison')
            plt.xlabel('Episode Number')
            plt.ylabel('Reward')

# %%
actor_lr = 0.0001
critic_lr = 0.001
gamma = 0.99
tau = 0.001
buffer_size = 100000
minibatch_size = 64
env = 'sat_inspection-v0'
random_seed = 1234
max_episodes = 3000
max_episode_len = 100
render_env = False
use_gym_monitor = False
test_episodes = 100
monitor_dir = './results/gym_ddpg'
summary_dir = './results/tf_ddpg'
args = {'actor_lr': actor_lr, 'critic_lr': critic_lr,'gamma': gamma,'tau': tau,'buffer_size': buffer_size,'minibatch_size': minibatch_size, 
       'env': env, 'random_seed': random_seed, 'max_episodes': max_episodes,'max_episode_len': max_episode_len,'render_env': render_env,
       'use_gym_monitor': use_gym_monitor, 'monitor_dir': monitor_dir, 'summary_dir': summary_dir, 'test_episodes': test_episodes}
main(args)
# Out:
# W0815 10:49:06.445215 139730476185344 deprecation_wrapper.py:119] From /home/ubuntu/anaconda3/lib/python3.6/site-packages/tflearn/layers/core.py:81: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0815 10:49:06.447073 139730476185344 deprecation.py:506] From /home/ubuntu/anaconda3/lib/python3.6/site-packages/tflearn/initializations.py:174: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0815 10:49:06.566296 139730476185344 deprecation.py:506] From /home/ubuntu/anaconda3/lib/python3.6/site-packages/tflearn/initializations.py:75: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W =  0.0011331552793256065
# W0815 10:49:07.040009 139730476185344 deprecation.py:323] From <ipython-input-2-e6f016854479>:42: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Beginning Training
# W0815 10:49:07.999882 139730476185344 meta_graph.py:449] Issue encountered when serializing data_preprocessing.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'NoneType' object has no attribute 'name'
# W0815 10:49:08.000503 139730476185344 meta_graph.py:449] Issue encountered when serializing data_augmentation.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'NoneType' object has no attribute 'name'
# W =  [[ 0.01586963 -0.04009107  0.04709516]]
# Actions Left 99 RTN:  [-0.00331167 -0.01181174  0.        ] Fuel Consumed 0.0 New Features 4066
# Actions Left 98 RTN:  [-0.00577707 -0.0070631   0.        ] Fuel Consumed 0.0 New Features 5519
# Actions Left 97 RTN:  [-0.0067662  -0.00050956  0.        ] Fuel Consumed 0.0 New Features 5826
# Actions Left 96 RTN:  [-0.0060263   0.00617419  0.        ] Fuel Consumed 0.0 New Features 5268
# Actions Left 95 RTN:  [-0.00374643  0.01128019  0.        ] Fuel Consumed 0.0 New Features 5378
# Actions Left 94 RTN:  [-0.0005092   0.01350365  0.        ] Fuel Consumed 0.0 New Features 5091
# Actions Left 93 RTN:  [0.00285815 0.01227639 0.        ] Fuel Consumed 0.0 New Features 4261
# Actions Left 92 RTN:  [0.00549513 0.00791201 0.        ] Fuel Consumed 0.0 New Features 4150
# Actions Left 91 RTN:  [0.00672788 0.0015258  0.        ] Fuel Consumed 0.0 New Features 4343
# Actions Left 90 RTN:  [ 0.00624139 -0.00525031 -0.        ] Fuel Consumed 0.0 New Features 2878
# Actions Left 89 RTN:  [ 0.00415998 -0.01068476 -0.        ] Fuel Consumed 0.0 New Features 2344
# Actions Left 88 RTN:  [ 0.00101552 -0.01338883 -0.        ] Fuel Consumed 0.0 New Features 1836
# Actions Left 87 RTN:  [-0.00238844 -0.01267151  0.        ] Fuel Consumed 0.0 New Features 1402
# Actions Left 86 RTN:  [-0.00518206 -0.00871611  0.        ] Fuel Consumed 0.0 New Features 1337
# Actions Left 85 RTN:  [-0.00665146 -0.0025334   0.        ] Fuel Consumed 0.0 New Features 1996
# Actions Left 84 RTN:  [-0.00642114  0.0042967   0.        ] Fuel Consumed 0.0 New Features 1244
# Actions Left 83 RTN:  [-0.00454996  0.01002881  0.        ] Fuel Consumed 0.0 New Features 836
# Actions Left 82 RTN:  [-0.00151609  0.01319817  0.        ] Fuel Consumed 0.0 New Features 925
# Actions Left 81 RTN:  [0.00190521 0.01299486 0.        ] Fuel Consumed 0.0 New Features 844
# Actions Left 80 RTN:  [0.00483965 0.00947085 0.        ] Fuel Consumed 0.0 New Features 955
# Actions Left 79 RTN:  [0.00653736 0.00352665 0.        ] Fuel Consumed 0.0 New Features 1390
# Actions Left 78 RTN:  [ 0.00656452 -0.00331874 -0.        ] Fuel Consumed 0.0 New Features 1169
# Actions Left 77 RTN:  [ 0.00491418 -0.00931607 -0.        ] Fuel Consumed 0.0 New Features 401
# Actions Left 76 RTN:  [ 0.00200807 -0.01293277 -0.        ] Fuel Consumed 0.0 New Features 537
# Actions Left 75 RTN:  [-0.00141119 -0.01324462  0.        ] Fuel Consumed 0.0 New Features 513
# Actions Left 74 RTN:  [-0.00446982 -0.01017195  0.        ] Fuel Consumed 0.0 New Features 457
# Actions Left 73 RTN:  [-0.00638624 -0.00449993  0.        ] Fuel Consumed 0.0 New Features 782
# Actions Left 72 RTN:  [-0.00667072  0.002322    0.        ] Fuel Consumed 0.0 New Features 1009
# Actions Left 71 RTN:  [-0.00525056  0.00855056  0.        ] Fuel Consumed 0.0 New Features 233
# Actions Left 70 RTN:  [-0.00248868  0.01259412  0.        ] Fuel Consumed 0.0 New Features 277
# Actions Left 69 RTN:  [0.00090917 0.01341937 0.        ] Fuel Consumed 0.0 New Features 499
# Actions Left 68 RTN:  [0.00407468 0.01081543 0.        ] Fuel Consumed 0.0 New Features 481
# Actions Left 67 RTN:  [0.00619895 0.00544772 0.        ] Fuel Consumed 0.0 New Features 475
# Actions Left 66 RTN:  [ 0.00673914 -0.0013121  -0.        ] Fuel Consumed 0.0 New Features 1027
# Actions Left 65 RTN:  [ 0.00555721 -0.00773663 -0.        ] Fuel Consumed 0.0 New Features 317
# Done because not enough new features seen
# Final Percent Coverage:  0.5416666666666666
# Actions Left 64 RTN:  [ 0.00295519 -0.01218414 -0.        ] Fuel Consumed 0.0 New Features 134
# | Reward: 52535 | Episode: 0 | Qmax: 0.0000
# W =  [[ 0.03057928 -0.02044699  0.02583694]]
# Actions Left 99 RTN:  [-0.00331167 -0.01181174  0.        ] Fuel Consumed 0.0 New Features 4135
# Actions Left 98 RTN:  [-0.07363561  0.1253744   0.0063328 ] Fuel Consumed 0.00015022621424404456 New Features 0
# Actions Left 97 RTN:  [-0.04818767 -0.26450112  0.01045068] Fuel Consumed 0.0002704247827889554 New Features 0
# Actions Left 96 RTN:  [-0.00175526 -0.11590324  0.0167164 ] Fuel Consumed 4.61480639616373e-05 New Features 0
# Actions Left 95 RTN:  [ 0.07980578 -0.19978625  0.02547881] Fuel Consumed 3.583326935257319e-05 New Features 0
# Actions Left 94 RTN:  [0.18591295 1.14966988 0.03397207] Fuel Consumed 0.0002876681902205448 New Features 0
# Actions Left 93 RTN:  [0.16431997 0.87933944 0.03378307] Fuel Consumed 0.0 New Features 0
# Actions Left 92 RTN:  [-0.10921683  1.63322024 -0.02288865] Fuel Consumed 0.00029012832276570057 New Features 0
# Actions Left 91 RTN:  [-0.44539268  2.36375182 -0.18161379] Fuel Consumed 0.00027731484268977584 New Features 0
# Actions Left 90 RTN:  [-0.74235746  0.48954768 -0.31521589] Fuel Consumed 0.0002165491997156498 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.031905864197530866
# Actions Left 89 RTN:  [-0.90861451  1.2878917  -0.36825551] Fuel Consumed 0.0 New Features 0
# | Reward: -793 | Episode: 1 | Qmax: 0.0000
# W =  [[-0.00725032 -0.02948832  0.027172  ]]
# Actions Left 99 RTN:  [ 0.01696818 -0.02367276  0.02086062] Fuel Consumed 6.839835373727297e-05 New Features 3221
# Actions Left 98 RTN:  [ 0.02843875 -0.04866203  0.03639052] Fuel Consumed 0.0 New Features 6070
# Actions Left 97 RTN:  [ 0.09720698 -0.48574159  0.13520032] Fuel Consumed 0.0002795702545531147 New Features 0
# Actions Left 96 RTN:  [ 0.21535927 -0.56819344  0.19945882] Fuel Consumed 0.0 New Features 0
# Actions Left 95 RTN:  [ 0.35270364 -0.78413572  0.2127476 ] Fuel Consumed 0.0 New Features 0
# Actions Left 94 RTN:  [ 0.4741431  -1.13528591  0.17167085] Fuel Consumed 0.0 New Features 0
# Actions Left 93 RTN:  [ 0.548645   -1.58881041  0.0867253 ] Fuel Consumed 0.0 New Features 0
# Actions Left 92 RTN:  [ 0.65281896 -4.38021805 -0.01854131] Fuel Consumed 0.0002659697056700722 New Features 0
# Actions Left 91 RTN:  [ 0.77711521 -4.92363675 -0.11907162] Fuel Consumed 0.0 New Features 0
# Actions Left 90 RTN:  [ 0.88980836 -5.59087631 -0.18917436] Fuel Consumed 0.0 New Features 0
# Actions Left 89 RTN:  [ 0.96210081 -6.3547661  -0.21093547] Fuel Consumed 0.0 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.07168981481481482
# Actions Left 88 RTN:  [ 0.88770091 -3.64704579 -0.16420144] Fuel Consumed 0.00025540750307367433 New Features 0
# | Reward: -1215 | Episode: 2 | Qmax: 0.0000
# W =  [[ 0.02486306 -0.0336      0.00644374]]
# Actions Left 99 RTN:  [-0.08380219  0.01089898 -0.10790578] Fuel Consumed 0.0003026172926677648 New Features 2086
# Actions Left 98 RTN:  [-0.19018099  0.35017221 -0.29613325] Fuel Consumed 0.0003603812940332272 New Features 0
# Actions Left 97 RTN:  [-0.3837541   0.79314954 -0.31077185] Fuel Consumed 0.000266694324534517 New Features 0
# Actions Left 96 RTN:  [-0.63748597  1.03295513 -0.24789819] Fuel Consumed 6.266220123136103e-05 New Features 0
# Actions Left 95 RTN:  [-0.90573023  1.64597775 -0.12167682] Fuel Consumed 0.0 New Features 0
# Actions Left 94 RTN:  [-1.09013243  2.21072848  0.0552206 ] Fuel Consumed 7.861153725798941e-05 New Features 0
# Actions Left 93 RTN:  [-1.15290195  3.21168719  0.21801505] Fuel Consumed 0.0 New Features 0
# Actions Left 92 RTN:  [-1.184915    4.33455054  0.42234216] Fuel Consumed 0.00033199729651857575 New Features 0
# Actions Left 91 RTN:  [-1.07478236  5.3402535   0.51880203] Fuel Consumed 0.0 New Features 0
# Actions Left 90 RTN:  [-0.85058455  6.1712774   0.4826872 ] Fuel Consumed 0.0 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.016095679012345678
# Actions Left 89 RTN:  [-0.56961307  6.73836333  0.32322643] Fuel Consumed 0.0 New Features 0
# | Reward: -660 | Episode: 3 | Qmax: 0.0051
# W =  [[ 0.00518582  0.02497428 -0.03170768]]
# Actions Left 99 RTN:  [ 0.01221409 -0.05478979  0.00705688] Fuel Consumed 0.00010314714930020965 New Features 3526
# Actions Left 98 RTN:  [ 0.07032973 -0.22740207  0.08800746] Fuel Consumed 0.000244556603206424 New Features 0
# Actions Left 97 RTN:  [ 0.12799239 -0.31193551  0.14646785] Fuel Consumed 0.0 New Features 0
# Actions Left 96 RTN:  [ 0.17046749 -0.44878835  0.16749984] Fuel Consumed 0.0 New Features 0
# Actions Left 95 RTN:  [ 0.18690095 -0.6164194   0.1457289 ] Fuel Consumed 0.0 New Features 0
# Actions Left 94 RTN:  [ 0.17309336 -0.7854224   0.08671839] Fuel Consumed 0.0 New Features 0
# Actions Left 93 RTN:  [ 0.29694074 -2.91843162  0.01862188] Fuel Consumed 0.0003548476226287125 New Features 0
# Actions Left 92 RTN:  [ 0.46091196 -2.32226089 -0.01334216] Fuel Consumed 0.00013493965433390384 New Features 0
# Actions Left 91 RTN:  [ 0.6164932  -3.21960999 -0.08311626] Fuel Consumed 0.00010797066267823294 New Features 0
# Actions Left 90 RTN:  [ 0.75771231 -4.47627857 -0.13429156] Fuel Consumed 7.945985147831526e-05 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.02720679012345679
# Actions Left 89 RTN:  [ 0.8368761  -5.16605932 -0.15114735] Fuel Consumed 0.0 New Features 0
# | Reward: -768 | Episode: 4 | Qmax: 0.0723
# W =  [[ 0.00647697  0.03856381 -0.00514308]]
# Actions Left 99 RTN:  [-0.00331167 -0.01181174  0.        ] Fuel Consumed 0.0 New Features 2938
# Actions Left 98 RTN:  [0.06169151 0.11219721 0.10790578] Fuel Consumed 0.0003964254059815263 New Features 0
# Actions Left 97 RTN:  [ 0.03005563 -0.0238377   0.1882373 ] Fuel Consumed 0.0 New Features 0
# Actions Left 96 RTN:  [-0.09013505 -0.08054714  0.22046665] Fuel Consumed 0.0 New Features 0
# Actions Left 95 RTN:  [-0.15124619 -0.23854404  0.30429063] Fuel Consumed 0.0003557904513739661 New Features 0
# Actions Left 94 RTN:  [-0.21800947 -1.68209665  0.35274182] Fuel Consumed 0.0002825176944745032 New Features 0
# Actions Left 93 RTN:  [-0.24727107 -2.20603605  0.36444488] Fuel Consumed 0.00026958733627600054 New Features 0
# Actions Left 92 RTN:  [-0.11479699 -1.90963395  0.28295342] Fuel Consumed 0.0 New Features 0
# Actions Left 91 RTN:  [ 0.1454492  -1.81841809  0.12915601] Fuel Consumed 0.0 New Features 0
# Actions Left 90 RTN:  [ 0.46696419 -2.03115749 -0.05764593] Fuel Consumed 0.0 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.022669753086419754
# Actions Left 89 RTN:  [ 0.74798516 -2.50003801 -0.24665526] Fuel Consumed 5.8357967946405195e-05 New Features 0
# | Reward: -708 | Episode: 5 | Qmax: 0.4966
# W =  [[0.00902985 0.05767555 0.08081994]]
# Actions Left 99 RTN:  [-0.00331167 -0.01181174  0.        ] Fuel Consumed 0.0 New Features 3251
# Actions Left 98 RTN:  [-0.00577707 -0.0070631   0.        ] Fuel Consumed 0.0 New Features 6185
# Actions Left 97 RTN:  [-0.0067662  -0.00050956  0.        ] Fuel Consumed 0.0 New Features 6258
# Actions Left 96 RTN:  [0.00541594 0.07650314 0.05916379] Fuel Consumed 0.00014375866653529076 New Features 5812
# Actions Left 95 RTN:  [0.00656739 0.05973365 0.10320885] Fuel Consumed 0.0 New Features 1187
# Actions Left 94 RTN:  [-0.02618857  1.62770892  0.03051429] Fuel Consumed 0.00033532489723569066 New Features 0
# Actions Left 93 RTN:  [-0.17466919  1.59931427 -0.04993997] Fuel Consumed 0.0 New Features 0
# Actions Left 92 RTN:  [-0.33746212  0.59460314 -0.10559858] Fuel Consumed 0.00015293175864820757 New Features 0
# Actions Left 91 RTN:  [-0.47921368  0.95027308 -0.13427117] Fuel Consumed 0.0 New Features 0
# Actions Left 90 RTN:  [-0.56370461  1.4241489  -0.12863208] Fuel Consumed 0.0 New Features 0
# Actions Left 89 RTN:  [-0.48037269 -1.05303705  0.01153849] Fuel Consumed 0.0003383487404908999 New Features 0
# Actions Left 88 RTN:  [-0.23737509 -0.63783528  0.14878929] Fuel Consumed 0.0 New Features 0
# Actions Left 87 RTN:  [ 0.15541013 -1.12808074  0.1552117 ] Fuel Consumed 0.00024092914394036727 New Features 0
# Actions Left 86 RTN:  [ 0.56183983 -1.44474048  0.12189417] Fuel Consumed 0.0 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.17510030864197532
# Actions Left 85 RTN:  [ 0.87801833 -2.13894441  0.05742778] Fuel Consumed 0.0 New Features 0
# | Reward: 1319 | Episode: 6 | Qmax: 2.2742
# W =  [[-0.02398628  0.0068868  -0.00884066]]
# Actions Left 99 RTN:  [-0.00331167 -0.01181174  0.        ] Fuel Consumed 0.0 New Features 4839
# Actions Left 98 RTN:  [-0.00504389  0.02390277 -0.00201807] Fuel Consumed 4.212142234769177e-05 New Features 4769
# Actions Left 97 RTN:  [-0.11042478  0.14386698  0.04277061] Fuel Consumed 0.0002182438783535608 New Features 0
# Actions Left 96 RTN:  [-0.21978219  0.28132198  0.07663019] Fuel Consumed 0.0 New Features 0
# Actions Left 95 RTN:  [-0.16936561 -0.15880942  0.19882382] Fuel Consumed 0.0003745492281647129 New Features 0
# Actions Left 94 RTN:  [-0.05210971 -0.01741699  0.27019812] Fuel Consumed 0.0 New Features 0
# Actions Left 93 RTN:  [ 0.10203381 -0.01782377  0.27252596] Fuel Consumed 0.0 New Features 0
# Actions Left 92 RTN:  [ 0.25367509 -0.17799524  0.2052125 ] Fuel Consumed 0.0 New Features 0
# Actions Left 91 RTN:  [ 0.36406372 -0.4750706   0.08545902] Fuel Consumed 0.0 New Features 0
# Actions Left 90 RTN:  [ 0.40499096 -0.85120461 -0.05613267] Fuel Consumed 0.0 New Features 0
# Actions Left 89 RTN:  [ 0.36988729 -0.27580149 -0.1445548 ] Fuel Consumed 0.00012520104356225734 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.0741358024691358
# Actions Left 88 RTN:  [ 0.26879427 -1.30585325 -0.23571448] Fuel Consumed 0.00012112342926251449 New Features 0
# | Reward: -1212 | Episode: 7 | Qmax: 6.5091
# W =  [[0.01394125 0.01351971 0.01765371]]
# Actions Left 99 RTN:  [ 0.05894938 -0.10295676  0.0270714 ] Fuel Consumed 0.0002466628909265705 New Features 3230
# Actions Left 98 RTN:  [ 0.04902662 -0.21798667  0.04722498] Fuel Consumed 0.0 New Features 0
# Actions Left 97 RTN:  [-0.03495233 -0.25110865  0.048909  ] Fuel Consumed 2.3295527764963652e-05 New Features 0
# Actions Left 96 RTN:  [-0.25147185  0.7245953   0.0536036 ] Fuel Consumed 0.0002589239575226768 New Features 0
# Actions Left 95 RTN:  [-0.58081524  0.88384745  0.03516206] Fuel Consumed 3.3427995397072524e-05 New Features 0
# Actions Left 94 RTN:  [-1.00669879  0.74800114 -0.06040198] Fuel Consumed 0.00032108775968211524 New Features 0
# Actions Left 93 RTN:  [-1.28516337  1.80793104 -0.13801795] Fuel Consumed 7.276129088816236e-06 New Features 0
# Actions Left 92 RTN:  [-1.31699795  3.28717746 -0.19819746] Fuel Consumed 8.874119913231084e-05 New Features 0
# Actions Left 91 RTN:  [-1.13188743  4.43633775 -0.20774705] Fuel Consumed 0.0 New Features 0
# Actions Left 90 RTN:  [-0.75909262  5.6227103  -0.22579784] Fuel Consumed 0.00015618426804824657 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.02492283950617284
# Actions Left 89 RTN:  [-0.3246083   6.04477954 -0.18621622] Fuel Consumed 0.0 New Features 0
# | Reward: -749 | Episode: 8 | Qmax: 13.1169
# W =  [[-0.00358599 -0.00352032  0.050251  ]]
# Actions Left 99 RTN:  [-0.15394676 -0.02620194  0.10790578] Fuel Consumed 0.0004011252947256246 New Features 1039
# Actions Left 98 RTN:  [-0.35401258  0.14610059  0.1882373 ] Fuel Consumed 0.0 New Features 0
# Actions Left 97 RTN:  [-0.65670472  0.57864161  0.32834533] Fuel Consumed 0.0003535550831467098 New Features 0
# Actions Left 96 RTN:  [-0.87657877  1.28718714  0.38457903] Fuel Consumed 0.0 New Features 0
# Actions Left 95 RTN:  [-1.06345506  2.49477897  0.2346246 ] Fuel Consumed 0.00033498511971211505 New Features 0
# Actions Left 94 RTN:  [-1.08979759  3.49863286  0.0247222 ] Fuel Consumed 0.0 New Features 0
# Actions Left 93 RTN:  [-0.97035106  3.59313948 -0.24272445] Fuel Consumed 0.00019659385058832038 New Features 0
# Actions Left 92 RTN:  [-0.66332461  4.38096189 -0.4481924 ] Fuel Consumed 0.0 New Features 0
# Actions Left 91 RTN:  [-0.1562631   2.52119631 -0.47294681] Fuel Consumed 0.0002819578462337015 New Features 0
# Actions Left 90 RTN:  [ 0.4562752   4.04014388 -0.34350564] Fuel Consumed 0.00021242759093485701 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.008016975308641976
# Actions Left 89 RTN:  [ 0.91529024  3.18053838 -0.11454346] Fuel Consumed 4.067306072082074e-05 New Features 0
# | Reward: -576 | Episode: 9 | Qmax: 23.8853
# W =  [[-0.00424665 -0.05971626  0.04914231]]
# Actions Left 99 RTN:  [-0.00331167 -0.01181174  0.        ] Fuel Consumed 0.0 New Features 3227
# Actions Left 98 RTN:  [-0.00577707 -0.0070631   0.        ] Fuel Consumed 0.0 New Features 5945
# Actions Left 97 RTN:  [ 0.01565422  0.37675244 -0.07950547] Fuel Consumed 0.0002922842601015376 New Features 0
# Actions Left 96 RTN:  [-0.0461304   0.30638302 -0.1386941 ] Fuel Consumed 0.0 New Features 0
# Actions Left 95 RTN:  [-0.17713128  0.31154951 -0.15949904] Fuel Consumed 1.0917325766830086e-05 New Features 0
# Actions Left 94 RTN:  [-0.18883214 -1.02335438 -0.11676424] Fuel Consumed 0.0003293445611879458 New Features 0
# Actions Left 93 RTN:  [-0.16632893 -1.9868769  -0.02002594] Fuel Consumed 0.000240349032548698 New Features 0
# Actions Left 92 RTN:  [-0.00490847 -1.79235292  0.0818386 ] Fuel Consumed 0.0 New Features 0
# Actions Left 91 RTN:  [0.30906658 0.30495903 0.05490982] Fuel Consumed 0.00040183707157337515 New Features 0
# Actions Left 90 RTN:  [0.57090511 2.49421082 0.11170992] Fuel Consumed 0.0003647672335878025 New Features 0
# Actions Left 89 RTN:  [0.60551481 2.892422   0.18254212] Fuel Consumed 0.00015740107691928934 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.0707716049382716
# Actions Left 88 RTN:  [0.34701529 2.24400315 0.20673631] Fuel Consumed 0.0 New Features 0
# | Reward: -1165 | Episode: 10 | Qmax: 36.0432
# W =  [[ 0.06697848 -0.03179021  0.00704194]]
# Actions Left 99 RTN:  [-0.00331167 -0.01181174  0.        ] Fuel Consumed 0.0 New Features 4870
# Actions Left 98 RTN:  [ 0.07659502 -0.07600084 -0.02811738] Fuel Consumed 0.00018926305842233252 New Features 3961
# Actions Left 97 RTN:  [ 0.15048546 -0.17987658 -0.04904965] Fuel Consumed 0.0 New Features 0
# Actions Left 96 RTN:  [ 0.1994777  -0.34795536 -0.05744776] Fuel Consumed 0.0 New Features 0
# Actions Left 95 RTN:  [ 0.17932524  0.42696842 -0.15031165] Fuel Consumed 0.0003024370934114827 New Features 0
# Actions Left 94 RTN:  [ 0.0390878   0.23195936 -0.20476161] Fuel Consumed 0.0 New Features 0
# Actions Left 93 RTN:  [-0.21647993  0.69486195 -0.22107105] Fuel Consumed 7.921249196253789e-05 New Features 0
# Actions Left 92 RTN:  [-0.56103141 -1.25418128 -0.11592945] Fuel Consumed 0.00037224460725778354 New Features 0
# Actions Left 91 RTN:  [-0.75047736 -0.55607323  0.01889073] Fuel Consumed 0.0 New Features 0
# Actions Left 90 RTN:  [-0.61024851 -0.78135854  0.17282507] Fuel Consumed 0.0002686599031265605 New Features 0
# Actions Left 89 RTN:  [-0.35272888  1.27527391  0.3179133 ] Fuel Consumed 0.00020042210130825772 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.06814043209876543
# Actions Left 88 RTN:  [-0.08983868  5.10125817  0.31797585] Fuel Consumed 0.00029629073742401996 New Features 0
# | Reward: -1158 | Episode: 11 | Qmax: 48.4733
# W =  [[-0.04608692 -0.00163936 -0.0203017 ]]
# Actions Left 99 RTN:  [-0.00331167 -0.01181174  0.        ] Fuel Consumed 0.0 New Features 4728
# Actions Left 98 RTN:  [-0.04685828 -0.01001293  0.04747054] Fuel Consumed 0.00015809674178770874 New Features 5160
# Actions Left 97 RTN:  [-0.06565206  0.06269109  0.08281046] Fuel Consumed 0.0 New Features 2697
# Actions Left 96 RTN:  [ 0.01075733 -0.4986699   0.04732527] Fuel Consumed 0.00021434688964326677 New Features 0
# Actions Left 95 RTN:  [ 1.73549926e-01 -4.97867018e-01 -2.47042163e-04] Fuel Consumed 0.0 New Features 0
# Actions Left 94 RTN:  [ 0.38112922 -0.69057392 -0.04775623] Fuel Consumed 0.0 New Features 0
# Actions Left 93 RTN:  [ 0.58045037 -1.09587584 -0.08306178] Fuel Consumed 0.0 New Features 0
# Actions Left 92 RTN:  [ 0.6997399  -3.13634773 -0.10045145] Fuel Consumed 0.0002114217385596006 New Features 0
# Actions Left 91 RTN:  [ 0.80313222 -3.74409973 -0.0921713 ] Fuel Consumed 0.0 New Features 0
# Actions Left 90 RTN:  [ 0.94487549 -6.40210104 -0.04079611] Fuel Consumed 0.00019820250938692882 New Features 0
# Actions Left 89 RTN:  [ 1.07119396 -7.05822027  0.02983253] Fuel Consumed 3.0551746400191456e-05 New Features 0
# Actions Left 88 RTN:  [ 1.2418888  -7.65107246  0.18433589] Fuel Consumed 0.0003006982790359962 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.09710648148148149
# Actions Left 87 RTN:  [ 1.31609872 -8.74689233  0.29167532] Fuel Consumed 0.0 New Features 0
# | Reward: -1458 | Episode: 12 | Qmax: 62.3195
# W =  [[ 0.05010818 -0.01163556 -0.0068907 ]]
# Actions Left 99 RTN:  [-0.11243618 -0.03638552 -0.003717  ] Fuel Consumed 0.0002350035684280658 New Features 3348
# Actions Left 98 RTN:  [-0.30380651  0.11675616  0.00804187] Fuel Consumed 7.62905592297346e-05 New Features 0
# Actions Left 97 RTN:  [-0.3637184   0.02942324  0.0161176 ] Fuel Consumed 0.00028432438171606796 New Features 0
# Actions Left 96 RTN:  [-0.28338686  0.08989389  0.05219568] Fuel Consumed 0.00014680981941560188 New Features 0
# Actions Left 95 RTN:  [-0.11117394  0.3172399   0.07493929] Fuel Consumed 0.0 New Features 0
# Actions Left 94 RTN:  [0.10890806 0.33962189 0.0785329 ] Fuel Consumed 0.0 New Features 0
# Actions Left 93 RTN:  [0.32061937 0.13640299 0.06205821] Fuel Consumed 0.0 New Features 0
# Actions Left 92 RTN:  [0.56339943 0.03795218 0.06987311] Fuel Consumed 0.00025705304584606976 New Features 0
# Actions Left 91 RTN:  [ 0.66445302 -0.60109734  0.05982303] Fuel Consumed 0.0 New Features 0
# Actions Left 90 RTN:  [0.53326878 0.06615239 0.00137727] Fuel Consumed 0.0001630206933098839 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.025833333333333333
# Actions Left 89 RTN:  [0.07822107 2.03685183 0.03658732] Fuel Consumed 0.0003644040670179535 New Features 0
# | Reward: -743 | Episode: 13 | Qmax: 78.4508
# W =  [[-0.05539493  0.04268259  0.03054591]]
# Actions Left 99 RTN:  [-0.00331167 -0.01181174  0.        ] Fuel Consumed 0.0 New Features 4398
# Actions Left 98 RTN:  [-0.16527909  0.29169344 -0.10449991] Fuel Consumed 0.0004221377828972572 New Features 0
# Actions Left 97 RTN:  [-0.39776706  0.46304141 -0.1822959 ] Fuel Consumed 0.0 New Features 0
# Actions Left 96 RTN:  [-0.6932652   1.18028598 -0.26592855] Fuel Consumed 0.00016438833175547532 New Features 0
# Actions Left 95 RTN:  [-0.95851451  1.88329227 -0.2816421 ] Fuel Consumed 0.0 New Features 0
# Actions Left 94 RTN:  [-1.09987616  4.13779671 -0.21651872] Fuel Consumed 0.00027434400866812794 New Features 0
# Actions Left 93 RTN:  [-1.08741036  4.02097386 -0.02839312] Fuel Consumed 0.00028610785032591603 New Features 0
# Actions Left 92 RTN:  [-0.98123711  4.90102839  0.16708733] Fuel Consumed 0.0 New Features 0
# Actions Left 91 RTN:  [-0.80861472  5.63541938  0.31987027] Fuel Consumed 0.0 New Features 0
# Actions Left 90 RTN:  [-0.61365514  6.17775823  0.39091354] Fuel Consumed 0.0 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.033935185185185186
# Actions Left 89 RTN:  [-0.44617834  6.5307334   0.36206272] Fuel Consumed 0.0 New Features 0
# | Reward: -823 | Episode: 14 | Qmax: 89.1311
# W =  [[-0.01925795 -0.01824634  0.02212952]]
# Actions Left 99 RTN:  [-0.00331167 -0.01181174  0.        ] Fuel Consumed 0.0 New Features 3341
# Actions Left 98 RTN:  [-0.00577707 -0.0070631   0.        ] Fuel Consumed 0.0 New Features 5807
# Actions Left 97 RTN:  [-0.01191872  0.01656056  0.00116729] Fuel Consumed 1.1067447742559689e-05 New Features 5300
# Actions Left 96 RTN:  [-0.01794278  0.02897272  0.00203629] Fuel Consumed 0.0 New Features 6579
# Actions Left 95 RTN:  [-0.02230985  0.04681398  0.00238493] Fuel Consumed 0.0 New Features 5103
# Actions Left 94 RTN:  [-0.14413254  1.33348255 -0.10578113] Fuel Consumed 0.0003620501596025134 New Features 0
# Actions Left 93 RTN:  [-0.31852993  1.4778187  -0.18691646] Fuel Consumed 0.0 New Features 0
# Actions Left 92 RTN:  [-0.50132695 -0.43645645 -0.3245336 ] Fuel Consumed 0.0003717226848991021 New Features 0
# Actions Left 91 RTN:  [-0.49614339 -0.10273089 -0.34737244] Fuel Consumed 0.00010662764624193987 New Features 0
# Actions Left 90 RTN:  [-0.28595556  0.59585293 -0.29556834] Fuel Consumed 0.00012342098774447547 New Features 0
# Actions Left 89 RTN:  [ 0.0201561   0.75958895 -0.16824226] Fuel Consumed 0.0 New Features 0
# Actions Left 88 RTN:  [0.34138495 0.417103   0.00361281] Fuel Consumed 1.7892876940556742e-05 New Features 0
# Actions Left 87 RTN:  [0.62555429 2.30182846 0.23919318] Fuel Consumed 0.00024789824042287494 New Features 0
# Actions Left 86 RTN:  [0.72726724 2.09176371 0.3444901 ] Fuel Consumed 0.0001723489596176219 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.20162037037037037
# Actions Left 85 RTN:  [0.48445296 5.25799878 0.35633628] Fuel Consumed 0.00024913082768792544 New Features 0
# | Reward: 1566 | Episode: 15 | Qmax: 105.0652
# W =  [[-0.00590131  0.00808169  0.0709421 ]]
# Actions Left 99 RTN:  [0.06213661 0.04333959 0.10486955] Fuel Consumed 0.000308719768026016 New Features 1867
# Actions Left 98 RTN:  [0.19041393 0.00073479 0.18294073] Fuel Consumed 0.0 New Features 0
# Actions Left 97 RTN:  [ 0.43281758 -0.50764637  0.233081  ] Fuel Consumed 0.00017916098117376386 New Features 0
# Actions Left 96 RTN:  [ 0.70204999 -0.95086664  0.22365638] Fuel Consumed 0.0 New Features 0
# Actions Left 95 RTN:  [ 0.92932095 -1.65349714  0.15707858] Fuel Consumed 0.0 New Features 0
# Actions Left 94 RTN:  [ 1.10807303 -1.00019999  0.04220018] Fuel Consumed 0.00035405793605810805 New Features 0
# Actions Left 93 RTN:  [ 1.02827369 -2.08949652 -0.08345609] Fuel Consumed 0.0 New Features 0
# Actions Left 92 RTN:  [ 0.7103937  -2.97101582 -0.18778599] Fuel Consumed 0.0 New Features 0
# Actions Left 91 RTN:  [ 0.23566412 -3.43841701 -0.24412904] Fuel Consumed 0.0 New Features 0
# Actions Left 90 RTN:  [-0.18400079 -6.35955954 -0.23966006] Fuel Consumed 0.0002622109252093444 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.014405864197530864
# Actions Left 89 RTN:  [-0.41923713 -5.89466438 -0.17394688] Fuel Consumed 0.0 New Features 0
# | Reward: -637 | Episode: 16 | Qmax: 119.3870
# W =  [[ 0.06611459  0.00231513 -0.0499582 ]]
# Actions Left 99 RTN:  [-0.03311088  0.02808454 -0.0607775 ] Fuel Consumed 0.00017688224365711993 New Features 3224
# Actions Left 98 RTN:  [-0.03542868  0.08822166 -0.10602392] Fuel Consumed 0.0 New Features 2037
# Actions Left 97 RTN:  [-0.00636113  0.13438272 -0.12417697] Fuel Consumed 0.0 New Features 0
# Actions Left 96 RTN:  [ 0.07224776  0.56712875 -0.07682453] Fuel Consumed 0.00019219132423898102 New Features 0
# Actions Left 95 RTN:  [ 0.0987416   0.44113254 -0.00984069] Fuel Consumed 0.0 New Features 0
# Actions Left 94 RTN:  [0.01798304 0.80508517 0.0278915 ] Fuel Consumed 0.00012744631295689656 New Features 0
# Actions Left 93 RTN:  [-0.13420202  0.79299629  0.05850434] Fuel Consumed 0.0 New Features 0
# Actions Left 92 RTN:  [-0.24426422  0.39353506  0.01266743] Fuel Consumed 0.00020979989001699236 New Features 0
# Actions Left 91 RTN:  [-0.33431228  0.65573774 -0.03752714] Fuel Consumed 4.960943537442507e-06 New Features 0
# Actions Left 90 RTN:  [-0.37960639  0.98443142 -0.07813181] Fuel Consumed 0.0 New Features 0
# Actions Left 89 RTN:  [-0.36857244  1.33102515 -0.09877067] Fuel Consumed 0.0 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.040594135802469136
# Actions Left 88 RTN:  [-0.30870566  1.61005964 -0.09048079] Fuel Consumed 1.4835319005786128e-05 New Features 0
# | Reward: -892 | Episode: 17 | Qmax: 148.7525
# W =  [[ 0.0029411   0.01749157 -0.05188264]]
# Actions Left 99 RTN:  [-0.00331167 -0.01181174  0.        ] Fuel Consumed 0.0 New Features 3488
# Actions Left 98 RTN:  [ 0.00700994 -0.0431002  -0.01772342] Fuel Consumed 5.464990510085045e-05 New Features 6101
# Actions Left 97 RTN:  [ 0.03090592 -0.04617187 -0.0309178 ] Fuel Consumed 0.0 New Features 6121
# Actions Left 96 RTN:  [ 0.03204404  0.16519591 -0.00868686] Fuel Consumed 9.737228863040595e-05 New Features 0
# Actions Left 95 RTN:  [-0.0438769   0.0694493   0.10133576] Fuel Consumed 0.00024206323237992093 New Features 3974
# Actions Left 94 RTN:  [-0.11396843  0.14604688  0.18545144] Fuel Consumed 0.0 New Features 0
# Actions Left 93 RTN:  [-0.1603274   0.28348685  0.22217685] Fuel Consumed 0.0 New Features 0
# Actions Left 92 RTN:  [-0.16032504 -0.20540591  0.2695329 ] Fuel Consumed 0.00017256907551025933 New Features 0
# Actions Left 91 RTN:  [-0.09206171 -0.04381427  0.2479731 ] Fuel Consumed 0.0 New Features 0
# Actions Left 90 RTN:  [0.0270153  0.01989686 0.16304623] Fuel Consumed 0.0 New Features 0
# Actions Left 89 RTN:  [ 0.16647706 -0.05147186  0.03645452] Fuel Consumed 0.0 New Features 0
# Actions Left 88 RTN:  [ 0.27866063 -1.06077486 -0.05254004] Fuel Consumed 0.0001349412175565364 New Features 0
# Actions Left 87 RTN:  [ 0.37221054 -1.34357892 -0.12813084] Fuel Consumed 0.0 New Features 0
# Actions Left 86 RTN:  [ 0.4232093  -1.70190595 -0.17097908] Fuel Consumed 0.0 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.15188271604938272
# Actions Left 85 RTN:  [ 0.44144886 -3.7559534  -0.15003225] Fuel Consumed 0.00010145289224311524 New Features 0
# | Reward: 1065 | Episode: 18 | Qmax: 191.0835
# W =  [[ 0.06380511 -0.01206085 -0.03095869]]
# Actions Left 99 RTN:  [-0.00331167 -0.01181174  0.        ] Fuel Consumed 0.0 New Features 4731
# Actions Left 98 RTN:  [ 0.0622099  -0.24684955 -0.07028683] Fuel Consumed 0.00028956039009219554 New Features 0
# Actions Left 97 RTN:  [ 0.17413146 -0.0538832  -0.08364601] Fuel Consumed 0.0001395170094099099 New Features 606
# Actions Left 96 RTN:  [ 0.30774654 -0.23354436 -0.07562529] Fuel Consumed 0.0 New Features 0
# Actions Left 95 RTN:  [0.3751829 0.010871  0.0368643] Fuel Consumed 0.00023478592694015896 New Features 0
# Actions Left 94 RTN:  [ 0.36991816 -0.38357976  0.1390893 ] Fuel Consumed 1.1491433533350557e-05 New Features 0
# Actions Left 93 RTN:  [ 0.23830887 -1.24774567  0.19332482] Fuel Consumed 0.00017666640682047715 New Features 0
# Actions Left 92 RTN:  [ 0.09887255 -1.36615693  0.1981672 ] Fuel Consumed 0.0 New Features 0
# Actions Left 91 RTN:  [-0.01280896 -1.35336558  0.15236991] Fuel Consumed 0.0 New Features 0
# Actions Left 90 RTN:  [-0.06819656 -1.25328492  0.06763601] Fuel Consumed 0.0 New Features 0
# Actions Left 89 RTN:  [-0.06333295 -1.33155554 -0.02495434] Fuel Consumed 4.165877355409569e-05 New Features 0
# Actions Left 88 RTN:  [ 0.02606192 -1.68260906 -0.04131661] Fuel Consumed 0.00016458275969935326 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.041180555555555554
# Actions Left 87 RTN:  [ 0.18256521 -1.71125169 -0.0471773 ] Fuel Consumed 0.0 New Features 0
# | Reward: -869 | Episode: 19 | Qmax: 198.9377
# W =  [[-0.0254588  -0.00297857  0.00892378]]
# Actions Left 99 RTN:  [-0.00331167 -0.01181174  0.        ] Fuel Consumed 0.0 New Features 4792
# Actions Left 98 RTN:  [-0.00577707 -0.0070631   0.        ] Fuel Consumed 0.0 New Features 5184
# Actions Left 97 RTN:  [ 0.00771922 -0.12777967 -0.00646709] Fuel Consumed 5.633936939703525e-05 New Features 0
# Actions Left 96 RTN:  [ 0.03557464 -0.16188676 -0.00867096] Fuel Consumed 2.7138629010884154e-05 New Features 0
# Actions Left 95 RTN:  [0.12595177 0.17874111 0.05178895] Fuel Consumed 0.00021356940333727088 New Features 0
# Actions Left 94 RTN:  [0.17728582 0.01283849 0.09901362] Fuel Consumed 0.0 New Features 0
# Actions Left 93 RTN:  [ 0.17645997 -0.17945338  0.12093635] Fuel Consumed 0.0 New Features 0
# Actions Left 92 RTN:  [ 0.12531717 -0.33376892  0.10772075] Fuel Consumed 1.0819370535381142e-05 New Features 0
# Actions Left 91 RTN:  [ 0.03474995 -0.42546096  0.06698009] Fuel Consumed 0.0 New Features 0
# Actions Left 90 RTN:  [-0.07209728 -0.41400902  0.00912333] Fuel Consumed 0.0 New Features 0
# Actions Left 89 RTN:  [-0.15649581 -0.456961   -0.05958802] Fuel Consumed 3.067094721681666e-05 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.07697530864197531
# Actions Left 88 RTN:  [-0.24997955  0.59935381 -0.05880802] Fuel Consumed 0.00015922085338277933 New Features 0
# | Reward: -1236 | Episode: 20 | Qmax: 161.7939
# W =  [[ 0.00982033 -0.00983474  0.05062098]]
# Actions Left 99 RTN:  [-0.00331167 -0.01181174  0.        ] Fuel Consumed 0.0 New Features 3471
# Actions Left 98 RTN:  [-0.00577707 -0.0070631   0.        ] Fuel Consumed 0.0 New Features 6228
# Actions Left 97 RTN:  [-0.0067662  -0.00050956  0.        ] Fuel Consumed 0.0 New Features 6355
# Actions Left 96 RTN:  [-0.0060263   0.00617419  0.        ] Fuel Consumed 0.0 New Features 5549
# Actions Left 95 RTN:  [-0.00374643  0.01128019  0.        ] Fuel Consumed 0.0 New Features 4624
# Actions Left 94 RTN:  [-0.0005092   0.01350365  0.        ] Fuel Consumed 0.0 New Features 4000
# Actions Left 93 RTN:  [0.00285815 0.01227639 0.        ] Fuel Consumed 0.0 New Features 3233
# Actions Left 92 RTN:  [0.00549513 0.00791201 0.        ] Fuel Consumed 0.0 New Features 2651
# Actions Left 91 RTN:  [0.00672788 0.0015258  0.        ] Fuel Consumed 0.0 New Features 2326
# Actions Left 90 RTN:  [ 0.00624139 -0.00525031 -0.        ] Fuel Consumed 0.0 New Features 1714
# Actions Left 89 RTN:  [ 0.00415998 -0.01068476 -0.        ] Fuel Consumed 0.0 New Features 1446
# Actions Left 88 RTN:  [ 0.00101552 -0.01338883 -0.        ] Fuel Consumed 0.0 New Features 1283
# Actions Left 87 RTN:  [-0.00238844 -0.01267151  0.        ] Fuel Consumed 0.0 New Features 1147
# Actions Left 86 RTN:  [-0.00518206 -0.00871611  0.        ] Fuel Consumed 0.0 New Features 1141
# Actions Left 85 RTN:  [-0.00665146 -0.0025334   0.        ] Fuel Consumed 0.0 New Features 967
# Actions Left 84 RTN:  [-0.00642114  0.0042967   0.        ] Fuel Consumed 0.0 New Features 811
# Actions Left 83 RTN:  [  0.29965541 -16.3761353   -0.15388116] Fuel Consumed 0.0008988028916862733 New Features 0
# Actions Left 82 RTN:  [  1.17876801 -43.33603459  -0.41282641] Fuel Consumed 0.0012297500929287605 New Features 0
# Actions Left 81 RTN:  [  2.6348589  -44.37192364  -0.56635816] Fuel Consumed 0.0 New Features 0
# Actions Left 80 RTN:  [  4.29581757 -47.03639093  -0.5751627 ] Fuel Consumed 0.0 New Features 0
# Actions Left 79 RTN:  [  5.73720249 -51.32175295  -0.43699012] Fuel Consumed 0.0 New Features 0
# Actions Left 78 RTN:  [  6.59068204 -56.80612265  -0.18714904] Fuel Consumed 0.0 New Features 0
# Actions Left 77 RTN:  [  6.63815798 -62.76121843   0.11051611] Fuel Consumed 0.0 New Features 0
# Actions Left 76 RTN:  [  5.86749832 -68.33846931   0.37993997] Fuel Consumed 0.0 New Features 0
# Actions Left 75 RTN:  [  4.47563748 -72.78585884   0.55227394] Fuel Consumed 0.0 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.36223765432098765
# Actions Left 74 RTN:  [  2.78435609 -69.12716508   0.77774351] Fuel Consumed 0.000489214663327917 New Features 0
# | Reward: 3294 | Episode: 21 | Qmax: 188.9820
# W =  [[-0.04778697  0.01468425  0.05235153]]
# Actions Left 99 RTN:  [-0.00331167 -0.01181174  0.        ] Fuel Consumed 0.0 New Features 3567
# Actions Left 98 RTN:  [-0.00577707 -0.0070631   0.        ] Fuel Consumed 0.0 New Features 5978
# Actions Left 97 RTN:  [-0.0067662  -0.00050956  0.        ] Fuel Consumed 0.0 New Features 5861
# Actions Left 96 RTN:  [ 0.03287617 -0.54897605  0.05384703] Fuel Consumed 0.000195385794066062 New Features 0
# Actions Left 95 RTN:  [ 0.23212131 -2.47077879  0.21207393] Fuel Consumed 0.00046750796259580795 New Features 0
# Actions Left 94 RTN:  [ 0.73080672 -8.87760506  0.47862431] Fuel Consumed 0.0010780531031483929 New Features 0
# Actions Left 93 RTN:  [  1.76093581 -12.860087     0.65421749] Fuel Consumed 0.000478935932466883 New Features 0
# Actions Left 92 RTN:  [  3.26837772 -21.83732575   0.75015904] Fuel Consumed 0.0009008645740110408 New Features 0
# Actions Left 91 RTN:  [  5.74931479 -40.10434744   0.90803873] Fuel Consumed 0.0016462627791844697 New Features 0
# Actions Left 90 RTN:  [  8.93785943 -55.79175251   1.08153606] Fuel Consumed 0.0010526875164860211 New Features 0
# Actions Left 89 RTN:  [ 12.13433501 -64.30437877   0.97753377] Fuel Consumed 0.0 New Features 0
# Actions Left 88 RTN:  [ 14.52227263 -75.73471733   0.62373242] Fuel Consumed 0.0 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.11887345679012346
# Actions Left 87 RTN:  [ 15.49145851 -88.91906658   0.11054243] Fuel Consumed 0.0 New Features 0
# | Reward: 724 | Episode: 22 | Qmax: 319.5557
# W =  [[-0.03213069 -0.0249694  -0.04631841]]
# Actions Left 99 RTN:  [-0.00331167 -0.01181174  0.        ] Fuel Consumed 0.0 New Features 4073
# Actions Left 98 RTN:  [-0.00577707 -0.0070631   0.        ] Fuel Consumed 0.0 New Features 5677
# Actions Left 97 RTN:  [-0.0067662  -0.00050956  0.        ] Fuel Consumed 0.0 New Features 5747
# Actions Left 96 RTN:  [-0.0060263   0.00617419  0.        ] Fuel Consumed 0.0 New Features 6028
# Actions Left 95 RTN:  [-0.00374643  0.01128019  0.        ] Fuel Consumed 0.0 New Features 5731
# Actions Left 94 RTN:  [-0.0005092   0.01350365  0.        ] Fuel Consumed 0.0 New Features 5179
# Actions Left 93 RTN:  [0.00285815 0.01227639 0.        ] Fuel Consumed 0.0 New Features 3662
# Actions Left 92 RTN:  [0.00549513 0.00791201 0.        ] Fuel Consumed 0.0 New Features 2830
# Actions Left 91 RTN:  [0.00672788 0.0015258  0.        ] Fuel Consumed 0.0 New Features 3614
# Actions Left 90 RTN:  [ 0.00624139 -0.00525031 -0.        ] Fuel Consumed 0.0 New Features 3440
# Actions Left 89 RTN:  [ 0.00415998 -0.01068476 -0.        ] Fuel Consumed 0.0 New Features 3430
# Actions Left 88 RTN:  [ 0.00101552 -0.01338883 -0.        ] Fuel Consumed 0.0 New Features 3006
# Actions Left 87 RTN:  [-0.00238844 -0.01267151  0.        ] Fuel Consumed 0.0 New Features 1520
# Actions Left 86 RTN:  [-0.00518206 -0.00871611  0.        ] Fuel Consumed 0.0 New Features 1153
# Actions Left 85 RTN:  [-0.00665146 -0.0025334   0.        ] Fuel Consumed 0.0 New Features 1416
# Actions Left 84 RTN:  [-0.00642114  0.0042967   0.        ] Fuel Consumed 0.0 New Features 1324
# Actions Left 83 RTN:  [-0.00454996  0.01002881  0.        ] Fuel Consumed 0.0 New Features 1657
# Actions Left 82 RTN:  [-0.00151609  0.01319817  0.        ] Fuel Consumed 0.0 New Features 1499
# Actions Left 81 RTN:  [ 0.29717883 -8.93685001  0.15869275] Fuel Consumed 0.0007159819242548048 New Features 0
# Actions Left 80 RTN:  [ 0.68617604 -9.26953271  0.27683314] Fuel Consumed 0.0 New Features 0
# Actions Left 79 RTN:  [  1.06607117 -10.00394189   0.32423157] Fuel Consumed 0.0 New Features 0
# Actions Left 78 RTN:  [  1.33978578 -11.07984535   0.28877584] Fuel Consumed 0.0 New Features 0
# Actions Left 77 RTN:  [  1.43737482 -12.34974542   0.1795263 ] Fuel Consumed 0.0 New Features 0
# Actions Left 76 RTN:  [  1.33390038 -13.61657053   0.0244006 ] Fuel Consumed 0.0 New Features 0
# Actions Left 75 RTN:  [  1.05580432 -14.68403485  -0.13696044] Fuel Consumed 0.0 New Features 0
# Actions Left 74 RTN:  [  0.67415134 -15.40679728  -0.26332259] Fuel Consumed 0.0 New Features 0
# Actions Left 73 RTN:  [  0.28646907 -15.72760181  -0.32239526] Fuel Consumed 0.0 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.470570987654321
# Actions Left 72 RTN:  [-8.17413663e-03 -1.56919088e+01 -2.99083027e-01] Fuel Consumed 0.0 New Features 0
# | Reward: 4395 | Episode: 23 | Qmax: 1198.2268
# W =  [[ 0.00300056 -0.01154743  0.02379888]]
# Actions Left 99 RTN:  [-0.00331167 -0.01181174  0.        ] Fuel Consumed 0.0 New Features 3363
# Actions Left 98 RTN:  [-0.00577707 -0.0070631   0.        ] Fuel Consumed 0.0 New Features 6210
# Actions Left 97 RTN:  [-0.0067662  -0.00050956  0.        ] Fuel Consumed 0.0 New Features 6298
# Actions Left 96 RTN:  [-0.0060263   0.00617419  0.        ] Fuel Consumed 0.0 New Features 5478
# Actions Left 95 RTN:  [-0.00374643  0.01128019  0.        ] Fuel Consumed 0.0 New Features 4661
# Actions Left 94 RTN:  [-0.0005092   0.01350365  0.        ] Fuel Consumed 0.0 New Features 3988
# Actions Left 93 RTN:  [0.00285815 0.01227639 0.        ] Fuel Consumed 0.0 New Features 3438
# Actions Left 92 RTN:  [0.00549513 0.00791201 0.        ] Fuel Consumed 0.0 New Features 3119
# Actions Left 91 RTN:  [0.00672788 0.0015258  0.        ] Fuel Consumed 0.0 New Features 3003
# Actions Left 90 RTN:  [ 0.00624139 -0.00525031 -0.        ] Fuel Consumed 0.0 New Features 2386
# Actions Left 89 RTN:  [ 0.00415998 -0.01068476 -0.        ] Fuel Consumed 0.0 New Features 1548
# Actions Left 88 RTN:  [ 0.00101552 -0.01338883 -0.        ] Fuel Consumed 0.0 New Features 1261
# Actions Left 87 RTN:  [-0.00238844 -0.01267151  0.        ] Fuel Consumed 0.0 New Features 1191
# Actions Left 86 RTN:  [-0.00518206 -0.00871611  0.        ] Fuel Consumed 0.0 New Features 1187
# Actions Left 85 RTN:  [-0.00665146 -0.0025334   0.        ] Fuel Consumed 0.0 New Features 1244
# Actions Left 84 RTN:  [-0.00642114  0.0042967   0.        ] Fuel Consumed 0.0 New Features 1141
# Actions Left 83 RTN:  [-0.00454996  0.01002881  0.        ] Fuel Consumed 0.0 New Features 790
# Actions Left 82 RTN:  [-0.00151609  0.01319817  0.        ] Fuel Consumed 0.0 New Features 687
# Actions Left 81 RTN:  [0.00190521 0.01299486 0.        ] Fuel Consumed 0.0 New Features 648
# Actions Left 80 RTN:  [0.00483965 0.00947085 0.        ] Fuel Consumed 0.0 New Features 736
# Actions Left 79 RTN:  [0.00653736 0.00352665 0.        ] Fuel Consumed 0.0 New Features 909
# Actions Left 78 RTN:  [ 0.00656452 -0.00331874 -0.        ] Fuel Consumed 0.0 New Features 911
# Actions Left 77 RTN:  [ 0.00491418 -0.00931607 -0.        ] Fuel Consumed 0.0 New Features 530
# Actions Left 76 RTN:  [ 0.00200807 -0.01293277 -0.        ] Fuel Consumed 0.0 New Features 385
# Actions Left 75 RTN:  [-0.00141119 -0.01324462  0.        ] Fuel Consumed 0.0 New Features 412
# Actions Left 74 RTN:  [-0.00446982 -0.01017195  0.        ] Fuel Consumed 0.0 New Features 464
# Actions Left 73 RTN:  [-0.00638624 -0.00449993  0.        ] Fuel Consumed 0.0 New Features 632
# Actions Left 72 RTN:  [-0.00667072  0.002322    0.        ] Fuel Consumed 0.0 New Features 701
# Actions Left 71 RTN:  [-0.00525056  0.00855056  0.        ] Fuel Consumed 0.0 New Features 404
# Actions Left 70 RTN:  [-0.00248868  0.01259412  0.        ] Fuel Consumed 0.0 New Features 302
# Actions Left 69 RTN:  [0.00090917 0.01341937 0.        ] Fuel Consumed 0.0 New Features 292
# Actions Left 68 RTN:  [0.00407468 0.01081543 0.        ] Fuel Consumed 0.0 New Features 344
# Actions Left 67 RTN:  [0.00619895 0.00544772 0.        ] Fuel Consumed 0.0 New Features 526
# Actions Left 66 RTN:  [ 0.00673914 -0.0013121  -0.        ] Fuel Consumed 0.0 New Features 616
# Actions Left 65 RTN:  [ 0.00555721 -0.00773663 -0.        ] Fuel Consumed 0.0 New Features 363
# Done because not enough new features seen
# Final Percent Coverage:  0.4657175925925926
# Actions Left 64 RTN:  [ 0.00295519 -0.01218414 -0.        ] Fuel Consumed 0.0 New Features 189
# | Reward: 3026 | Episode: 24 | Qmax: 558.6273
# W =  [[-0.00097575  0.04426135  0.03929156]]
# Actions Left 99 RTN:  [-0.00331167 -0.01181174  0.        ] Fuel Consumed 0.0 New Features 3648
# Actions Left 98 RTN:  [-0.00577707 -0.0070631   0.        ] Fuel Consumed 0.0 New Features 5517
# Actions Left 97 RTN:  [-0.0067662  -0.00050956  0.        ] Fuel Consumed 0.0 New Features 6267
# Actions Left 96 RTN:  [-0.0060263   0.00617419  0.        ] Fuel Consumed 0.0 New Features 5099
# Actions Left 95 RTN:  [-0.00374643  0.01128019  0.        ] Fuel Consumed 0.0 New Features 5135
# Actions Left 94 RTN:  [-0.0005092   0.01350365  0.        ] Fuel Consumed 0.0 New Features 4411
# Actions Left 93 RTN:  [ 0.09945675 -3.01057065  0.11231368] Fuel Consumed 0.00046905233213299474 New Features 0
# Actions Left 92 RTN:  [ 0.42368875 -6.10236168  0.27378466] Fuel Consumed 0.0003806663621169459 New Features 0
# Actions Left 91 RTN:  [  1.2301371  -18.51287832   0.53105686] Fuel Consumed 0.001214335036860727 New Features 0
# Actions Left 90 RTN:  [  3.11271615 -36.41904318   0.98089584] Fuel Consumed 0.0016901559371290283 New Features 0
# Actions Left 89 RTN:  [  5.71942266 -45.10249876   1.46988013] Fuel Consumed 0.0008147773824764831 New Features 0
# Actions Left 88 RTN:  [  8.70645731 -59.41123058   1.9090879 ] Fuel Consumed 0.000964897551514016 New Features 0
# Actions Left 87 RTN:  [ 11.55180015 -82.04473072   2.50706456] Fuel Consumed 0.0017557308024496816 New Features 0
# Actions Left 86 RTN:  [  14.1269814  -106.03080755    3.1911136 ] Fuel Consumed 0.001881395977510156 New Features 0
# Actions Left 85 RTN:  [  15.79670415 -118.7188795     3.05917839] Fuel Consumed 0.0 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.23207561728395062
# Actions Left 84 RTN:  [  16.13439637 -132.45577416    2.14550048] Fuel Consumed 0.0 New Features 0
# | Reward: 1865 | Episode: 25 | Qmax: 567.3039
# W =  [[-0.01457779 -0.00844591 -0.08271181]]
# Actions Left 99 RTN:  [ 0.00378606 -0.00312347  0.07534403] Fuel Consumed 0.00017640402804895372 New Features 4016
# Actions Left 98 RTN:  [ 0.01798464 -0.00210144  0.13143465] Fuel Consumed 0.0 New Features 2364
# Actions Left 97 RTN:  [ 0.05006914 -1.31233255  0.58453089] Fuel Consumed 0.0011875135195918009 New Features 0
# Actions Left 96 RTN:  [ 0.75728917 -6.74679254  1.647348  ] Fuel Consumed 0.0023089551060738074 New Features 0
# Actions Left 95 RTN:  [  2.44750442 -10.93122088   2.65188968] Fuel Consumed 0.0011164785658650189 New Features 0
# Actions Left 94 RTN:  [  4.92983752 -16.77521496   3.18318946] Fuel Consumed 0.000721412995365361 New Features 0
# Actions Left 93 RTN:  [  7.79495195 -24.580889     3.20700444] Fuel Consumed 0.0008024627009520052 New Features 0
# Actions Left 92 RTN:  [ 10.34868255 -32.22910689   2.40681995] Fuel Consumed 0.0 New Features 0
# Actions Left 91 RTN:  [ 11.93908497 -42.04252772   0.99159649] Fuel Consumed 0.0 New Features 0
# Actions Left 90 RTN:  [ 12.15974766 -52.8021835   -0.67701962] Fuel Consumed 0.0 New Features 0
# Actions Left 89 RTN:  [ 10.95428244 -63.04730528  -2.17263008] Fuel Consumed 0.0 New Features 0
# Done because did not see target for a long time
# Final Percent Coverage:  0.049228395061728394
# ...
# Actions Left 92 RTN:  [0.00549513 0.00791201 0.        ] Fuel Consumed 0.0 New Features 3466
# Actions Left 91 RTN:  [0.00672788 0.0015258  0.        ] Fuel Consumed 0.0 New Features 4477
# Actions Left 90 RTN:  [ 0.00624139 -0.00525031 -0.        ] Fuel Consumed 0.0 New Features 4626
# Actions Left 89 RTN:  [ 0.00415998 -0.01068476 -0.        ] Fuel Consumed 0.0 New Features 2175
# Actions Left 88 RTN:  [ 0.00101552 -0.01338883 -0.        ] Fuel Consumed 0.0 New Features 1383
# Actions Left 87 RTN:  [-0.00238844 -0.01267151  0.        ] Fuel Consumed 0.0 New Features 1463
# Actions Left 86 RTN:  [-0.00518206 -0.00871611  0.        ] Fuel Consumed 0.0 New Features 1861
# Actions Left 85 RTN:  [-0.00665146 -0.0025334   0.        ] Fuel Consumed 0.0 New Features 2831
# Actions Left 84 RTN:  [-0.00642114  0.0042967   0.        ] Fuel Consumed 0.0 New Features 1829
# Actions Left 83 RTN:  [-0.00454996  0.01002881  0.        ] Fuel Consumed 0.0 New Features 520
# Actions Left 82 RTN:  [-0.00151609  0.01319817  0.        ] Fuel Consumed 0.0 New Features 510
# Actions Left 81 RTN:  [0.00190521 0.01299486 0.        ] Fuel Consumed 0.0 New Features 690
# Actions Left 80 RTN:  [0.00483965 0.00947085 0.        ] Fuel Consumed 0.0 New Features 991
# Actions Left 79 RTN:  [0.00653736 0.00352665 0.        ] Fuel Consumed 0.0 New Features 1791
# Actions Left 78 RTN:  [ 0.00656452 -0.00331874 -0.        ] Fuel Consumed 0.0 New Features 1301
# Actions Left 77 RTN:  [ 0.00491418 -0.00931607 -0.        ] Fuel Consumed 0.0 New Features 306
# Actions Left 76 RTN:  [ 0.00200807 -0.01293277 -0.        ] Fuel Consumed 0.0 New Features 242
# Actions Left 75 RTN:  [-0.00141119 -0.01324462  0.        ] Fuel Consumed 0.0 New Features 399
# Actions Left 74 RTN:  [-0.00446982 -0.01017195  0.        ] Fuel Consumed 0.0 New Features 613
# Actions Left 73 RTN:  [-0.00638624 -0.00449993  0.        ] Fuel Consumed 0.0 New Features 1131
# Actions Left 72 RTN:  [-0.00667072  0.002322    0.        ] Fuel Consumed 0.0 New Features 1243
# Actions Left 71 RTN:  [-0.00525056  0.00855056  0.        ] Fuel Consumed 0.0 New Features 243
# Done because not enough new features seen
# Final Percent Coverage:  0.513641975308642
# Actions Left 70 RTN:  [-0.00248868  0.01259412  0.        ] Fuel Consumed 0.0 New Features 134
# | Reward: 49625 | Episode: 7
# W =  [[0.04678906 0.01471829 0.03012573]]
# Actions Left 99 RTN:  [-0.00331167 -0.01181174  0.        ] Fuel Consumed 0.0 New Features 4319
# Actions Left 98 RTN:  [-0.00577707 -0.0070631   0.        ] Fuel Consumed 0.0 New Features 5601
# Actions Left 97 RTN:  [-0.0067662  -0.00050956  0.        ] Fuel Consumed 0.0 New Features 5539
# Actions Left 96 RTN:  [-0.0060263   0.00617419  0.        ] Fuel Consumed 0.0 New Features 5247
# Actions Left 95 RTN:  [-0.00374643  0.01128019  0.        ] Fuel Consumed 0.0 New Features 6440
# Actions Left 94 RTN:  [-0.0005092   0.01350365  0.        ] Fuel Consumed 0.0 New Features 5053
# Actions Left 93 RTN:  [0.00285815 0.01227639 0.        ] Fuel Consumed 0.0 New Features 3537
# Actions Left 92 RTN:  [0.00549513 0.00791201 0.        ] Fuel Consumed 0.0 New Features 3014
# Actions Left 91 RTN:  [0.00672788 0.0015258  0.        ] Fuel Consumed 0.0 New Features 4265
# Actions Left 90 RTN:  [ 0.00624139 -0.00525031 -0.        ] Fuel Consumed 0.0 New Features 4069
# Actions Left 89 RTN:  [ 0.00415998 -0.01068476 -0.        ] Fuel Consumed 0.0 New Features 3648
# Actions Left 88 RTN:  [ 0.00101552 -0.01338883 -0.        ] Fuel Consumed 0.0 New Features 2147
# Actions Left 87 RTN:  [-0.00238844 -0.01267151  0.        ] Fuel Consumed 0.0 New Features 1676
# Actions Left 86 RTN:  [-0.00518206 -0.00871611  0.        ] Fuel Consumed 0.0 New Features 1812
# Actions Left 85 RTN:  [-0.00665146 -0.0025334   0.        ] Fuel Consumed 0.0 New Features 1631
# Actions Left 84 RTN:  [-0.00642114  0.0042967   0.        ] Fuel Consumed 0.0 New Features 2591
# Actions Left 83 RTN:  [-0.00454996  0.01002881  0.        ] Fuel Consumed 0.0 New Features 991
# Actions Left 82 RTN:  [-0.00151609  0.01319817  0.        ] Fuel Consumed 0.0 New Features 879
# Actions Left 81 RTN:  [0.00190521 0.01299486 0.        ] Fuel Consumed 0.0 New Features 918
# Actions Left 80 RTN:  [0.00483965 0.00947085 0.        ] Fuel Consumed 0.0 New Features 799
# Actions Left 79 RTN:  [0.00653736 0.00352665 0.        ] Fuel Consumed 0.0 New Features 1689
# Actions Left 78 RTN:  [ 0.00656452 -0.00331874 -0.        ] Fuel Consumed 0.0 New Features 1124
# Actions Left 77 RTN:  [ 0.00491418 -0.00931607 -0.        ] Fuel Consumed 0.0 New Features 969
# Actions Left 76 RTN:  [ 0.00200807 -0.01293277 -0.        ] Fuel Consumed 0.0 New Features 415
# Actions Left 75 RTN:  [-0.00141119 -0.01324462  0.        ] Fuel Consumed 0.0 New Features 398
# Actions Left 74 RTN:  [-0.00446982 -0.01017195  0.        ] Fuel Consumed 0.0 New Features 650
# Actions Left 73 RTN:  [-0.00638624 -0.00449993  0.        ] Fuel Consumed 0.0 New Features 787
# Actions Left 72 RTN:  [-0.00667072  0.002322    0.        ] Fuel Consumed 0.0 New Features 1233
# Actions Left 71 RTN:  [-0.00525056  0.00855056  0.        ] Fuel Consumed 0.0 New Features 569
# Actions Left 70 RTN:  [-0.00248868  0.01259412  0.        ] Fuel Consumed 0.0 New Features 331
# Actions Left 69 RTN:  [0.00090917 0.01341937 0.        ] Fuel Consumed 0.0 New Features 412
# Actions Left 68 RTN:  [0.00407468 0.01081543 0.        ] Fuel Consumed 0.0 New Features 255
# Actions Left 67 RTN:  [0.00619895 0.00544772 0.        ] Fuel Consumed 0.0 New Features 647
# Actions Left 66 RTN:  [ 0.00673914 -0.0013121  -0.        ] Fuel Consumed 0.0 New Features 912
# Actions Left 65 RTN:  [ 0.00555721 -0.00773663 -0.        ] Fuel Consumed 0.0 New Features 434
# Actions Left 64 RTN:  [ 0.00295519 -0.01218414 -0.        ] Fuel Consumed 0.0 New Features 311
# Done because not enough new features seen
# Final Percent Coverage:  0.5826388888888889
# Actions Left 63 RTN:  [-0.000402   -0.01351811  0.        ] Fuel Consumed 0.0 New Features 198
# | Reward: 56651 | Episode: 8
# W =  [[ 0.00604009 -0.00630264  0.04448278]]
# Actions Left 99 RTN:  [-0.00331167 -0.01181174  0.        ] Fuel Consumed 0.0 New Features 3473
# Actions Left 98 RTN:  [-0.00577707 -0.0070631   0.        ] Fuel Consumed 0.0 New Features 6352
# Actions Left 97 RTN:  [-0.0067662  -0.00050956  0.        ] Fuel Consumed 0.0 New Features 6235
# Actions Left 96 RTN:  [-0.0060263   0.00617419  0.        ] Fuel Consumed 0.0 New Features 5442
# Actions Left 95 RTN:  [-0.00374643  0.01128019  0.        ] Fuel Consumed 0.0 New Features 4591
# Actions Left 94 RTN:  [-0.0005092   0.01350365  0.        ] Fuel Consumed 0.0 New Features 3680
# Actions Left 93 RTN:  [0.00285815 0.01227639 0.        ] Fuel Consumed 0.0 New Features 2983
# Actions Left 92 RTN:  [0.00549513 0.00791201 0.        ] Fuel Consumed 0.0 New Features 2533
# Actions Left 91 RTN:  [0.00672788 0.0015258  0.        ] Fuel Consumed 0.0 New Features 2093
# Actions Left 90 RTN:  [ 0.00624139 -0.00525031 -0.        ] Fuel Consumed 0.0 New Features 1726
# Actions Left 89 RTN:  [ 0.00415998 -0.01068476 -0.        ] Fuel Consumed 0.0 New Features 1455
# Actions Left 88 RTN:  [ 0.00101552 -0.01338883 -0.        ] Fuel Consumed 0.0 New Features 1352
# Actions Left 87 RTN:  [-0.00238844 -0.01267151  0.        ] Fuel Consumed 0.0 New Features 1101
# Actions Left 86 RTN:  [-0.00518206 -0.00871611  0.        ] Fuel Consumed 0.0 New Features 1025
# Actions Left 85 RTN:  [-0.00665146 -0.0025334   0.        ] Fuel Consumed 0.0 New Features 922
# Actions Left 84 RTN:  [-0.00642114  0.0042967   0.        ] Fuel Consumed 0.0 New Features 841
# Actions Left 83 RTN:  [-0.00454996  0.01002881  0.        ] Fuel Consumed 0.0 New Features 712
# Actions Left 82 RTN:  [-0.00151609  0.01319817  0.        ] Fuel Consumed 0.0 New Features 704
# Actions Left 81 RTN:  [0.00190521 0.01299486 0.        ] Fuel Consumed 0.0 New Features 675
# Actions Left 80 RTN:  [0.00483965 0.00947085 0.        ] Fuel Consumed 0.0 New Features 681
# Actions Left 79 RTN:  [0.00653736 0.00352665 0.        ] Fuel Consumed 0.0 New Features 627
# Actions Left 78 RTN:  [ 0.00656452 -0.00331874 -0.        ] Fuel Consumed 0.0 New Features 519
# Actions Left 77 RTN:  [ 0.00491418 -0.00931607 -0.        ] Fuel Consumed 0.0 New Features 465
# Actions Left 76 RTN:  [ 0.00200807 -0.01293277 -0.        ] Fuel Consumed 0.0 New Features 431
# Actions Left 75 RTN:  [-0.00141119 -0.01324462  0.        ] Fuel Consumed 0.0 New Features 459
# Actions Left 74 RTN:  [-0.00446982 -0.01017195  0.        ] Fuel Consumed 0.0 New Features 460
# Actions Left 73 RTN:  [-0.00638624 -0.00449993  0.        ] Fuel Consumed 0.0 New Features 469
# Actions Left 72 RTN:  [-0.00667072  0.002322    0.        ] Fuel Consumed 0.0 New Features 391
# Actions Left 71 RTN:  [-0.00525056  0.00855056  0.        ] Fuel Consumed 0.0 New Features 342
# Actions Left 70 RTN:  [-0.00248868  0.01259412  0.        ] Fuel Consumed 0.0 New Features 351
# Actions Left 69 RTN:  [0.00090917 0.01341937 0.        ] Fuel Consumed 0.0 New Features 390
# Actions Left 68 RTN:  [0.00407468 0.01081543 0.        ] Fuel Consumed 0.0 New Features 351
# Actions Left 67 RTN:  [0.00619895 0.00544772 0.        ] Fuel Consumed 0.0 New Features 359
# Actions Left 66 RTN:  [ 0.00673914 -0.0013121  -0.        ] Fuel Consumed 0.0 New Features 319
# Actions Left 65 RTN:  [ 0.00555721 -0.00773663 -0.        ] Fuel Consumed 0.0 New Features 284
# Actions Left 64 RTN:  [ 0.00295519 -0.01218414 -0.        ] Fuel Consumed 0.0 New Features 252
# Actions Left 63 RTN:  [-0.000402   -0.01351811  0.        ] Fuel Consumed 0.0 New Features 300
# Actions Left 62 RTN:  [-0.00365647 -0.01139767  0.        ] Fuel Consumed 0.0 New Features 306
# Actions Left 61 RTN:  [-0.00597656 -0.00636466  0.        ] Fuel Consumed 0.0 New Features 324
# Actions Left 60 RTN:  [-0.0067694   0.00029477  0.        ] Fuel Consumed 0.0 New Features 276
# Actions Left 59 RTN:  [-0.00583238  0.00687888  0.        ] Fuel Consumed 0.0 New Features 241
# Actions Left 58 RTN:  [-0.00340496  0.01170515  0.        ] Fuel Consumed 0.0 New Features 212
# Actions Left 57 RTN:  [-0.00010744  0.0135403   0.        ] Fuel Consumed 0.0 New Features 223
# Actions Left 56 RTN:  [0.00321754 0.01191535 0.        ] Fuel Consumed 0.0 New Features 231
# Actions Left 55 RTN:  [0.00572031 0.00724555 0.        ] Fuel Consumed 0.0 New Features 233
# Actions Left 54 RTN:  [0.00676131 0.00072423 0.        ] Fuel Consumed 0.0 New Features 235
# Actions Left 53 RTN:  [ 0.00607453 -0.00598217 -0.        ] Fuel Consumed 0.0 New Features 209
# Done because not enough new features seen
# Final Percent Coverage:  0.44753086419753085
# Actions Left 52 RTN:  [ 0.00383546 -0.01115988 -0.        ] Fuel Consumed 0.0 New Features 165
# | Reward: 3114 | Episode: 9
# Reward List for Zero Policy [50457, 51852, 52587, 54863, 56919, 49840, 2786, 49625, 56651, 3114]
# Actions List for Zero Policy  [array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]), array([0, 0, 0, 0]),  ...
# Average Reward for Zero Policy  42869.4
# Average Pct Coverage for Zero Policy  0.5247222222222223
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-13dc1ac11d6f> in <module>
#      17        'env': env, 'random_seed': random_seed, 'max_episodes': max_episodes,'max_episode_len': max_episode_len,'render_env': render_env,
#      18        'use_gym_monitor': use_gym_monitor, 'monitor_dir': monitor_dir, 'summary_dir': summary_dir, 'test_episodes': test_episodes}
# ---> 19 main(args)
#
# <ipython-input-10-2cc57ad85d59> in main(args)
#      75
#      76             plt.figure(1)
# ---> 77             plt.plot(reward_list, color = "blue")
#      78             plt.plot(rand_list, color = "red")
#      79             plt.plot(zero_list,color = "green")
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2787     return gca().plot(
#    2788         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2789         is not None else {}), **kwargs)
#    2790
#    2791
#
# TypeError: plot() missing 1 required positional argument: 'ys'
